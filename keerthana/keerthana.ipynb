# %%
import pandas as pd

# %%
df=pd.read_csv("sorry - Sheet3.csv")
df
# Out:
#            Language  Ways to say sorry  Edit
# 0          Albanian        Më vjen keq  Edit
# 1            Basque          Sentitzen  Edit
# 2        Belarusian           прабачце  Edit
# 3           Bosnian             izvini  Edit
# 4         Bulgarian          съжалявам  Edit
# ..              ...                ...   ...
# 108       Sundanese             punten  Edit
# 109        Language  Ways to say sorry   NaN
# 110       Esperanto           bedaŭras  Edit
# 111  Haitian Creole             regrèt  Edit
# 112           Latin           paenitet  Edit
#
# [113 rows x 3 columns]

# %%
df.drop(['Edit'],axis=1)
df.drop(df.index[df['Ways to say sorry'] == 'Ways to say sorry'],inplace=True)

# %%
df["I'M Sorry"]=df["Ways to say sorry"]+" Keerthana   "+"("+df["Language"]+")"

# %%
for i in range(len(df)) :
    print(df.iloc[i, 3])
# Out:
# Më vjen keq Keerthana   (Albanian)
# Sentitzen Keerthana   (Basque)
# прабачце Keerthana   (Belarusian)
# izvini Keerthana   (Bosnian)
# съжалявам Keerthana   (Bulgarian)
# ho sento Keerthana   (Catalan)
# scusa Keerthana   (Corsican)
# oprostite Keerthana   (Croatian)
# Promiňte Keerthana   (Czech)
# undskyld Keerthana   (Danish)
# Sorry Keerthana   (Dutch)
# Vabandust Keerthana   (Estonian)
# anteeksi Keerthana   (Finnish)
# Pardon Keerthana   (French)
# Sorry Keerthana   (Frisian)
# Sentímolo Keerthana   (Galician)
# Es tut uns leid Keerthana   (German)
# συγνώμη [sygnómi] Keerthana   (Greek)
# sajnálom Keerthana   (Hungarian)
# Fyrirgefðu Keerthana   (Icelandic)
# tá brón orainn Keerthana   (Irish)
# scusa Keerthana   (Italian)
# Atvainojiet Keerthana   (Latvian)
# atsiprašau Keerthana   (Lithuanian)
# entschëllegt Keerthana   (Luxembourgish)
# жал Keerthana   (Macedonian)
# sorry Keerthana   (Maltese)
# Beklager Keerthana   (Norwegian)
# Przepraszam Keerthana   (Polish)
# ...
